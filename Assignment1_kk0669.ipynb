# %% [markdown]
# <a href="https://colab.research.google.com/github/kkandanala9/Hello-World/blob/master/Assignment1_kk0669.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 1: Exploratory Data Analysis of NBA Salaries
#
# Use **`nba_salaries.csv`** to perform a short exploratory data analysis (EDA).
#
# Your goal is to provide code to either answer the question or to make the required plots. For every question mentioning [Text], explain **what the graph tells you about the data**.
#
# ### Part A — Understand the dataset (25pts)
#
# 1. [Code] Display the first 10 rows.
# 2. [Code] Report the number of rows and columns.
# 3. [Code] Display column names and data types.
# 4. [Code] Check whether any values are missing.
# 5. [Code] Compute descriptive statistics for `SALARY`.
#
# ### Part B — Explore categorical variables (30pts)
#
# 6. [Code] How many players are represented at each `POSITION`?
# 7. [Code] Create an appropriate visualization of the position distribution.
# 8. [Code] Identify the five teams with the most players in the dataset.
#
# ### Part C — Explore salary as a numerical variable (15+15+5+5 = 40pts)
#
# 9. [Code] Create a histogram of player salaries.
# 10. [Code] Regenerate the histogram by trying at least **two different choices of bins**.
# 11. [Text] Describe the shape of the salary distribution. Is it symmetric or skewed?
# 12. [Text] Identify the five highest-paid players.
#
# ### Part D — Compare categories (30pts)
#
# 13. [Code] Compute the average salary by `POSITION`.
# 14. [Code] Create a bar chart of average salary by position.
# 15. [Code] Choose **two NBA teams** and compare their player salary distributions using an appropriate visualization.
#
# ### [Optional] Part E — Interpretation (5pts)
#
# [Text] Write a short paragraph (4–6 sentences) summarizing at least **three insights** from your analysis. Include at least one observation about:
# - a categorical distribution,
# - the overall salary distribution, and
# - a comparison between groups.

# %%
# ============================================
# NBA EXPLORATORY DATA ANALYSIS
# ============================================

# Start by importing all required libraries (e.g Pandas, NumPy, etc) and loading the data:

# import pandas as pd
# import numpy as np
# import more libraries here

nba = pd.read_csv("nba_salaries.csv")
nba = nba.rename(columns={"'15-'16 SALARY": "SALARY"})

# Part A: Understand the dataset
# 1. Display the first 10 rows


# 2. Number of rows and columns


# 3. Column names and data types


# 4. Missing values


# 5. Descriptive statistics for salary


# Part B: Categorical variables
# 6. Player counts by position


# 7. Visualize the position distribution


# 8. Five teams with the most players


# Part C: Salary distribution
# 9-10. Histogram(s) with at least two different bin choices


# 11. Describe the shape in a Markdown cell below your plot.


# 12. Five highest-paid players


# Part D: Compare categories
# 13. Average salary by position


# 14. Bar chart of average salary by position


# 15. Compare salary distributions for two teams of your choice


# Part E:
# Add a Markdown cell below and summarize at least three insights.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Part A

# %% [markdown]
# Part A.1

# %%
nba.head(10)
# Out:
#              PLAYER POSITION           TEAM     SALARY
# 0      Paul Millsap       PF  Atlanta Hawks  18.671659
# 1        Al Horford        C  Atlanta Hawks  12.000000
# 2    Tiago Splitter        C  Atlanta Hawks   9.756250
# 3       Jeff Teague       PG  Atlanta Hawks   8.000000
# 4       Kyle Korver       SG  Atlanta Hawks   5.746479
# 5   Thabo Sefolosha       SF  Atlanta Hawks   4.000000
# 6        Mike Scott       PF  Atlanta Hawks   3.333333
# 7     Kent Bazemore       SF  Atlanta Hawks   2.000000
# 8   Dennis Schroder       PG  Atlanta Hawks   1.763400
# 9  Tim Hardaway Jr.       SG  Atlanta Hawks   1.304520

# %% [markdown]
# Part A.2

# %%
nba.shape
# Out:
# (417, 4)

# %% [markdown]
# Part A.3

# %%
nba.dtypes
# Out:
# PLAYER       object
# POSITION     object
# TEAM         object
# SALARY      float64
# dtype: object

# %% [markdown]
# Part A.4

# %%
nba.isnull().values.any()
# Out:
# np.False_

# %% [markdown]
# Part A.5

# %%
nba.describe()
# Out:
#            SALARY
# count  417.000000
# mean     5.074814
# std      5.221437
# min      0.030888
# 25%      1.270964
# 50%      3.000000
# 75%      7.000000
# max     25.000000

# %% [markdown]
# Part B

# %% [markdown]
# Part B.6

# %%
nba[["POSITION"]].value_counts()
# Out:
# POSITION
# SG          96
# PG          85
# PF          85
# SF          82
# C           69
# Name: count, dtype: int64

# %% [markdown]
# Part B.7

# %%
nba[["POSITION"]].value_counts().plot.bar()
# Out:
# <Axes: xlabel='POSITION'>

# %% [markdown]
# Part B.8

# %%
nba[["TEAM"]].value_counts()
# Out:
# TEAM
# Memphis Grizzlies         21
# Charlotte Hornets         18
# Phoenix Suns              17
# Washington Wizards        17
# Utah Jazz                 17
# Toronto Raptors           17
# New Orleans Pelicans      16
# Oklahoma City Thunder     16
# Boston Celtics            15
# Orlando Magic             14
# Atlanta Hawks             14
# Denver Nuggets            14
# Golden State Warriors     14
# Portland Trail Blazers    14
# Brooklyn Nets             13
# New York Knicks           13
# Minnesota Timberwolves    13
# Milwaukee Bucks           13
# San Antonio Spurs         13
# Philadelphia 76ers        13
# Indiana Pacers            13
# Los Angeles Clippers      13
# Chicago Bulls             12
# Houston Rockets           12
# Miami Heat                12
# Los Angeles Lakers        11
# Dallas Mavericks          11
# Sacramento Kings          11
# Detroit Pistons           10
# Cleveland Cavaliers       10
# Name: count, dtype: int64

# %% [markdown]
# Part C

# %% [markdown]
# Part C.9

# %%
nba[["SALARY"]].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Part C.10

# %%
nba[["SALARY"]].plot.hist(bins = 20)
nba[["SALARY"]].plot.hist(bins = 40)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Part C.11

# %% [markdown]
# The shape of the histogram is skewwed. The reason behind this is that it doesn't look symmetrical at all; therfore this is a skewwed shape on the histogram.

# %% [markdown]
# Part C.12

# %%
nba.sort_values("SALARY")
# Out:
#                      PLAYER POSITION                 TEAM     SALARY
# 267  Thanasis Antetokounmpo       SF      New York Knicks   0.030888
# 326            Jordan McRae       SG         Phoenix Suns   0.049709
# 327          Cory Jefferson       PF         Phoenix Suns   0.049709
# 324         Orlando Johnson       SG         Phoenix Suns   0.055722
# 325            Phil Pressey       PG         Phoenix Suns   0.055722
# ..                      ...      ...                  ...        ...
# 131           Dwight Howard        C      Houston Rockets  22.359364
# 255         Carmelo Anthony       SF      New York Knicks  22.875000
# 72             LeBron James       SF  Cleveland Cavaliers  22.970500
# 29              Joe Johnson       SF        Brooklyn Nets  24.894863
# 169             Kobe Bryant       SF   Los Angeles Lakers  25.000000
#
# [417 rows x 4 columns]

# %% [markdown]
# The top five highest players in the NBA are Dwight Howard, Carmelo Anthony, LeBron James, Joe Johnson, and Kobe Bryant.

# %% [markdown]
# Part D

# %% [markdown]
# Part D.13

# %%
nba[["POSITION", "SALARY"]].groupby(by=["POSITION"]).mean()
# Out:
#             SALARY
# POSITION
# C         6.082913
# PF        4.951344
# PG        5.165487
# SF        5.532675
# SG        3.988195

# %% [markdown]
# Part D.14
